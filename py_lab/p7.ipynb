# %%
import numpy as np
from urllib.request import urlopen
import urllib
import matplotlib.pyplot as plt # Visuals
import seaborn as sns
import sklearn as skl
import pandas as pd

# %%
Cleveland_data_URL = 'http://archive.ics.uci.edu/ml/machine-learning-databases/heart-disease/processed.hungarian.data'

# %%
np.set_printoptions(threshold=np.nan)

# %%
names = ['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach', 'exang', 'oldpeak', 'slope', 'ca', 'thal', 'heartdisease']
heartDisease = pd.read_csv(urlopen(Cleveland_data_URL), names = names)

# %%
heartDisease.head()
del heartDisease['ca']
del heartDisease['slope']
del heartDisease['thal']
del heartDisease['oldpeak']
heartDisease = heartDisease.replace('?', np.nan)
heartDisease.dtypes
heartDisease.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'heartdisease'],
#       dtype='object')

# %%
import pandas as pd
from pgmpy.models import BayesianModel
from pgmpy.estimators import MaximumLikelihoodEstimator, BayesianEstimator


#from pgmpy.estimators import MaximumLikelihoodEstimator, BayesianEstimator
model = BayesianModel([('age', 'trestbps'), ('age', 'fbs'), ('sex', 'trestbps'), ('sex', 'trestbps'), ('exang', 'trestbps'),('trestbps','heartdisease'),('fbs','heartdisease'),('heartdisease','restecg'),('heartdisease','thalach'),('heartdisease','chol')])

# %%
# Learing CPDs using Maximum Likelihood Estimators
model.fit(heartDisease, estimator=MaximumLikelihoodEstimator)
#for cpd in model.get_cpds():
# print("CPD of {variable}:".format(variable=cpd.variable))
 # print(cpd)
print(model.get_cpds('age'))
print(model.get_cpds('chol'))
print(model.get_cpds('sex'))
model.get_independencies()
# Out:
# ╒═════════╤════════════╕
# │ age(28) │ 0.00383142 │
# ├─────────┼────────────┤
# │ age(29) │ 0.00383142 │
# ├─────────┼────────────┤
# │ age(30) │ 0.00383142 │
# ├─────────┼────────────┤
# │ age(31) │ 0.00766284 │
# ├─────────┼────────────┤
# │ age(32) │ 0.0153257  │
# ├─────────┼────────────┤
# │ age(33) │ 0.00766284 │
# ├─────────┼────────────┤
# │ age(34) │ 0.0153257  │
# ├─────────┼────────────┤
# │ age(35) │ 0.0191571  │
# ├─────────┼────────────┤
# │ age(36) │ 0.0191571  │
# ├─────────┼────────────┤
# │ age(37) │ 0.0306513  │
# ├─────────┼────────────┤
# │ age(38) │ 0.0191571  │
# ├─────────┼────────────┤
# │ age(39) │ 0.0344828  │
# ├─────────┼────────────┤
# │ age(40) │ 0.0191571  │
# ├─────────┼────────────┤
# │ age(41) │ 0.0383142  │
# ├─────────┼────────────┤
# │ age(42) │ 0.0268199  │
# ├─────────┼────────────┤
# │ age(43) │ 0.0421456  │
# ├─────────┼────────────┤
# │ age(44) │ 0.0268199  │
# ├─────────┼────────────┤
# │ age(45) │ 0.0229885  │
# ├─────────┼────────────┤
# │ age(46) │ 0.045977   │
# ├─────────┼────────────┤
# │ age(47) │ 0.0344828  │
# ├─────────┼────────────┤
# │ age(48) │ 0.0613027  │
# ├─────────┼────────────┤
# │ age(49) │ 0.0421456  │
# ├─────────┼────────────┤
# │ age(50) │ 0.045977   │
# ├─────────┼────────────┤
# │ age(51) │ 0.0344828  │
# ├─────────┼────────────┤
# │ age(52) │ 0.0574713  │
# ├─────────┼────────────┤
# │ age(53) │ 0.0383142  │
# ├─────────┼────────────┤
# │ age(54) │ 0.0842912  │
# ├─────────┼────────────┤
# │ age(55) │ 0.0536398  │
# ├─────────┼────────────┤
# │ age(56) │ 0.0306513  │
# ├─────────┼────────────┤
# │ age(57) │ 0.0191571  │
# ├─────────┼────────────┤
# │ age(58) │ 0.0344828  │
# ├─────────┼────────────┤
# │ age(59) │ 0.0229885  │
# ├─────────┼────────────┤
# │ age(60) │ 0.00766284 │
# ├─────────┼────────────┤
# │ age(61) │ 0.00766284 │
# ├─────────┼────────────┤
# │ age(62) │ 0.00766284 │
# ├─────────┼────────────┤
# │ age(63) │ 0.00383142 │
# ├─────────┼────────────┤
# │ age(65) │ 0.0114943  │
# ├─────────┼────────────┤
# │ age(66) │ 0          │
# ╘═════════╧════════════╛
# ╒══════════════╤══════════════════════╤══════════════════════╕
# │ heartdisease │ heartdisease(0)      │ heartdisease(1)      │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(100)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(117)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(129)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(132)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(147)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(156)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(160)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(161)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(163)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(164)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(166)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(167)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(168)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(171)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(172)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(173)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(175)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(179)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(180)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(182)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(184)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(186)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(187)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(188)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(190)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(193)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(194)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(195)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(196)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(198)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(200)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(201)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(202)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(204)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(205)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(206)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(207)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(208)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(209)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(210)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(211)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(212)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(213)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(214)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(215)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(216)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(217)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(218)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(219)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(220)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(221)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(222)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(223)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(224)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(225)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(226)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(227)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(228)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(229)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(230)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(231)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(233)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(234)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(237)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(238)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(240)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(241)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(242)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(243)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(245)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(246)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(247)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(248)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(249)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(250)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(251)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(253)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(254)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(255)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(256)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(257)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(259)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(260)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(263)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(264)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(265)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(266)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(267)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(268)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(269)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(270)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(271)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(272)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(273)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(274)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(275)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(276)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(277)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(279)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(280)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(281)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(282)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(283)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(284)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(285)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(287)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(288)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(289)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(290)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(291)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(292)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(294)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(295)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(297)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(298)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(303)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(305)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(306)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(307)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(308)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(309)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(312)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(315)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(318)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(320)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(326)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(328)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(329)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(331)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(336)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(338)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(339)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(340)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(341)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(342)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(344)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(347)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(355)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(358)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(365)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(388)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(392)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(393)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(394)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(404)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(412)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(466)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(468)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(491)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(518)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(529)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(603)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(85)     │ 0.006535947712418301 │ 0.006535947712418301 │
# ╘══════════════╧══════════════════════╧══════════════════════╛
# ╒════════╤══════════╕
# │ sex(0) │ 0.264368 │
# ├────────┼──────────┤
# │ sex(1) │ 0.735632 │
# ╘════════╧══════════╛
# (age _|_ exang, sex)
# (age _|_ thalach, restecg, chol | heartdisease)
# (age _|_ exang | sex)
# (age _|_ sex | exang)
# (age _|_ exang, sex | fbs)
# (age _|_ restecg, chol | thalach, heartdisease)
# (age _|_ thalach, chol | restecg, heartdisease)
# (age _|_ thalach, restecg, chol | heartdisease, sex)
# (age _|_ thalach, restecg | chol, heartdisease)
# (age _|_ thalach, restecg, chol | heartdisease, trestbps)
# (age _|_ thalach, restecg, chol | exang, heartdisease)
# (age _|_ thalach, restecg, chol | fbs, heartdisease)
# (age _|_ exang | fbs, sex)
# (age _|_ thalach, restecg, chol, heartdisease | fbs, trestbps)
# (age _|_ sex | exang, fbs)
# (age _|_ chol | thalach, restecg, heartdisease)
# (age _|_ restecg, chol | thalach, heartdisease, sex)
# (age _|_ restecg | thalach, chol, heartdisease)
# (age _|_ restecg, chol | thalach, heartdisease, trestbps)
# (age _|_ restecg, chol | thalach, exang, heartdisease)
# (age _|_ restecg, chol | thalach, fbs, heartdisease)
# (age _|_ restecg, chol, heartdisease | thalach, fbs, trestbps)
# (age _|_ thalach, chol | restecg, heartdisease, sex)
# (age _|_ thalach | restecg, chol, heartdisease)
# (age _|_ thalach, chol | restecg, heartdisease, trestbps)
# (age _|_ thalach, chol | restecg, heartdisease, exang)
# (age _|_ thalach, chol | restecg, fbs, heartdisease)
# (age _|_ thalach, chol, heartdisease | restecg, fbs, trestbps)
# (age _|_ thalach, restecg | chol, heartdisease, sex)
# (age _|_ thalach, restecg, chol | heartdisease, sex, trestbps)
# (age _|_ thalach, restecg, chol | exang, heartdisease, sex)
# (age _|_ thalach, restecg, chol | fbs, heartdisease, sex)
# (age _|_ thalach, restecg | chol, heartdisease, trestbps)
# (age _|_ thalach, restecg | exang, chol, heartdisease)
# (age _|_ thalach, restecg | fbs, chol, heartdisease)
# (age _|_ thalach, restecg, chol | exang, heartdisease, trestbps)
# (age _|_ thalach, restecg, chol | fbs, heartdisease, trestbps)
# (age _|_ thalach, restecg, chol | exang, fbs, heartdisease)
# (age _|_ thalach, restecg, chol, heartdisease | fbs, sex, trestbps)
# (age _|_ thalach, restecg, heartdisease | fbs, chol, trestbps)
# (age _|_ thalach, restecg, chol, heartdisease | exang, fbs, trestbps)
# (age _|_ chol | thalach, restecg, heartdisease, sex)
# (age _|_ chol | thalach, restecg, heartdisease, trestbps)
# (age _|_ chol | thalach, restecg, heartdisease, exang)
# (age _|_ chol | thalach, restecg, fbs, heartdisease)
# (age _|_ chol, heartdisease | thalach, restecg, fbs, trestbps)
# (age _|_ restecg | thalach, chol, heartdisease, sex)
# (age _|_ restecg, chol | thalach, heartdisease, sex, trestbps)
# (age _|_ restecg, chol | thalach, exang, heartdisease, sex)
# (age _|_ restecg, chol | thalach, fbs, heartdisease, sex)
# (age _|_ restecg | thalach, chol, heartdisease, trestbps)
# (age _|_ restecg | thalach, exang, chol, heartdisease)
# (age _|_ restecg | thalach, fbs, chol, heartdisease)
# (age _|_ restecg, chol | thalach, exang, heartdisease, trestbps)
# (age _|_ restecg, chol | thalach, fbs, heartdisease, trestbps)
# (age _|_ restecg, chol | thalach, exang, fbs, heartdisease)
# (age _|_ restecg, chol, heartdisease | thalach, fbs, sex, trestbps)
# (age _|_ restecg, heartdisease | thalach, fbs, chol, trestbps)
# (age _|_ restecg, chol, heartdisease | thalach, exang, fbs, trestbps)
# (age _|_ thalach | restecg, chol, heartdisease, sex)
# (age _|_ thalach, chol | restecg, heartdisease, sex, trestbps)
# (age _|_ thalach, chol | restecg, heartdisease, sex, exang)
# (age _|_ thalach, chol | restecg, fbs, heartdisease, sex)
# (age _|_ thalach | restecg, chol, heartdisease, trestbps)
# (age _|_ thalach | restecg, chol, heartdisease, exang)
# (age _|_ thalach | fbs, restecg, chol, heartdisease)
# (age _|_ thalach, chol | exang, restecg, heartdisease, trestbps)
# (age _|_ thalach, chol | restecg, fbs, heartdisease, trestbps)
# (age _|_ thalach, chol | restecg, fbs, heartdisease, exang)
# (age _|_ thalach, chol, heartdisease | restecg, fbs, sex, trestbps)
# (age _|_ thalach, heartdisease | fbs, restecg, chol, trestbps)
# (age _|_ thalach, chol, heartdisease | exang, restecg, fbs, trestbps)
# (age _|_ thalach, restecg | chol, heartdisease, sex, trestbps)
# (age _|_ thalach, restecg | exang, chol, heartdisease, sex)
# (age _|_ thalach, restecg | fbs, chol, heartdisease, sex)
# (age _|_ thalach, restecg, chol | exang, heartdisease, sex, trestbps)
# (age _|_ thalach, restecg, chol | fbs, heartdisease, sex, trestbps)
# (age _|_ thalach, restecg, chol | exang, fbs, heartdisease, sex)
# (age _|_ thalach, restecg | exang, chol, heartdisease, trestbps)
# (age _|_ thalach, restecg | fbs, chol, heartdisease, trestbps)
# (age _|_ thalach, restecg | fbs, exang, chol, heartdisease)
# (age _|_ thalach, restecg, chol | exang, fbs, heartdisease, trestbps)
# (age _|_ thalach, restecg, heartdisease | fbs, chol, sex, trestbps)
# (age _|_ thalach, restecg, chol, heartdisease | exang, fbs, sex, trestbps)
# (age _|_ thalach, restecg, heartdisease | fbs, exang, chol, trestbps)
# (age _|_ chol | thalach, heartdisease, sex, trestbps, restecg)
# (age _|_ chol | thalach, heartdisease, sex, restecg, exang)
# (age _|_ chol | thalach, heartdisease, sex, restecg, fbs)
# (age _|_ chol | thalach, heartdisease, trestbps, restecg, exang)
# (age _|_ chol | thalach, heartdisease, trestbps, restecg, fbs)
# (age _|_ chol | thalach, heartdisease, restecg, fbs, exang)
# (age _|_ chol, heartdisease | thalach, sex, trestbps, restecg, fbs)
# (age _|_ heartdisease | thalach, chol, trestbps, restecg, fbs)
# (age _|_ chol, heartdisease | thalach, trestbps, restecg, fbs, exang)
# (age _|_ restecg | thalach, heartdisease, sex, chol, trestbps)
# (age _|_ restecg | thalach, heartdisease, sex, chol, exang)
# (age _|_ restecg | thalach, heartdisease, sex, chol, fbs)
# (age _|_ restecg, chol | thalach, heartdisease, sex, trestbps, exang)
# (age _|_ restecg, chol | thalach, heartdisease, sex, trestbps, fbs)
# (age _|_ restecg, chol | thalach, heartdisease, sex, exang, fbs)
# (age _|_ restecg | thalach, heartdisease, chol, trestbps, exang)
# (age _|_ restecg | thalach, heartdisease, chol, trestbps, fbs)
# (age _|_ restecg | thalach, heartdisease, chol, exang, fbs)
# (age _|_ restecg, chol | thalach, heartdisease, trestbps, exang, fbs)
# (age _|_ restecg, heartdisease | thalach, sex, chol, trestbps, fbs)
# (age _|_ restecg, chol, heartdisease | thalach, sex, trestbps, exang, fbs)
# (age _|_ restecg, heartdisease | thalach, chol, trestbps, exang, fbs)
# (age _|_ thalach | heartdisease, sex, chol, trestbps, restecg)
# (age _|_ thalach | heartdisease, sex, chol, restecg, exang)
# (age _|_ thalach | heartdisease, sex, chol, restecg, fbs)
# (age _|_ thalach, chol | restecg, heartdisease, sex, trestbps, exang)
# (age _|_ thalach, chol | heartdisease, sex, trestbps, restecg, fbs)
# (age _|_ thalach, chol | heartdisease, sex, restecg, fbs, exang)
# (age _|_ thalach | restecg, heartdisease, chol, trestbps, exang)
# (age _|_ thalach | heartdisease, chol, trestbps, restecg, fbs)
# (age _|_ thalach | heartdisease, chol, restecg, fbs, exang)
# (age _|_ thalach, chol | restecg, heartdisease, trestbps, exang, fbs)
# (age _|_ thalach, heartdisease | sex, chol, trestbps, restecg, fbs)
# (age _|_ thalach, chol, heartdisease | restecg, sex, trestbps, exang, fbs)
# (age _|_ thalach, heartdisease | restecg, chol, trestbps, exang, fbs)
# (age _|_ thalach, restecg | heartdisease, sex, chol, trestbps, exang)
# (age _|_ thalach, restecg | heartdisease, sex, chol, trestbps, fbs)
# (age _|_ thalach, restecg | heartdisease, sex, chol, exang, fbs)
# (age _|_ thalach, restecg, chol | heartdisease, sex, trestbps, exang, fbs)
# (age _|_ thalach, restecg | heartdisease, chol, trestbps, exang, fbs)
# (age _|_ thalach, restecg, heartdisease | sex, chol, trestbps, exang, fbs)
# (age _|_ chol | thalach, heartdisease, sex, trestbps, restecg, exang)
# (age _|_ chol | thalach, heartdisease, sex, trestbps, restecg, fbs)
# (age _|_ chol | thalach, heartdisease, sex, restecg, fbs, exang)
# (age _|_ chol | thalach, heartdisease, trestbps, restecg, fbs, exang)
# (age _|_ heartdisease | thalach, sex, chol, trestbps, restecg, fbs)
# (age _|_ chol, heartdisease | thalach, sex, trestbps, restecg, fbs, exang)
# (age _|_ heartdisease | thalach, chol, trestbps, restecg, fbs, exang)
# (age _|_ restecg | thalach, heartdisease, sex, chol, trestbps, exang)
# (age _|_ restecg | thalach, heartdisease, sex, chol, trestbps, fbs)
# (age _|_ restecg | thalach, heartdisease, sex, chol, exang, fbs)
# (age _|_ restecg, chol | thalach, heartdisease, sex, trestbps, exang, fbs)
# (age _|_ restecg | thalach, heartdisease, chol, trestbps, exang, fbs)
# (age _|_ restecg, heartdisease | thalach, sex, chol, trestbps, exang, fbs)
# (age _|_ thalach | heartdisease, sex, chol, trestbps, restecg, exang)
# (age _|_ thalach | heartdisease, sex, chol, trestbps, restecg, fbs)
# (age _|_ thalach | heartdisease, sex, chol, restecg, fbs, exang)
# (age _|_ thalach, chol | restecg, heartdisease, sex, trestbps, exang, fbs)
# (age _|_ thalach | restecg, heartdisease, chol, trestbps, exang, fbs)
# (age _|_ thalach, heartdisease | restecg, sex, chol, trestbps, exang, fbs)
# (age _|_ thalach, restecg | heartdisease, sex, chol, trestbps, exang, fbs)
# (age _|_ chol | thalach, heartdisease, sex, trestbps, restecg, fbs, exang)
# (age _|_ heartdisease | thalach, sex, chol, trestbps, restecg, fbs, exang)
# (age _|_ restecg | thalach, heartdisease, sex, chol, trestbps, exang, fbs)
# (age _|_ thalach | heartdisease, sex, chol, trestbps, restecg, fbs, exang)
# (trestbps _|_ fbs | age)
# (trestbps _|_ thalach, restecg, chol | heartdisease)
# (trestbps _|_ restecg, chol | thalach, heartdisease)
# (trestbps _|_ thalach, restecg, chol | age, heartdisease)
# (trestbps _|_ fbs | age, sex)
# (trestbps _|_ fbs | age, exang)
# (trestbps _|_ thalach, chol | restecg, heartdisease)
# (trestbps _|_ thalach, restecg, chol | heartdisease, sex)
# (trestbps _|_ thalach, restecg | chol, heartdisease)
# (trestbps _|_ thalach, restecg, chol | exang, heartdisease)
# (trestbps _|_ thalach, restecg, chol | fbs, heartdisease)
# (trestbps _|_ restecg, chol | thalach, age, heartdisease)
# (trestbps _|_ chol | thalach, restecg, heartdisease)
# (trestbps _|_ restecg, chol | thalach, heartdisease, sex)
# (trestbps _|_ restecg | thalach, chol, heartdisease)
# (trestbps _|_ restecg, chol | thalach, exang, heartdisease)
# (trestbps _|_ restecg, chol | thalach, fbs, heartdisease)
# (trestbps _|_ thalach, chol | age, restecg, heartdisease)
# (trestbps _|_ thalach, restecg, chol | age, heartdisease, sex)
# (trestbps _|_ thalach, restecg | age, chol, heartdisease)
# (trestbps _|_ thalach, restecg, chol | age, exang, heartdisease)
# (trestbps _|_ thalach, restecg, chol | age, fbs, heartdisease)
# (trestbps _|_ fbs | age, exang, sex)
# (trestbps _|_ thalach, chol | restecg, heartdisease, sex)
# (trestbps _|_ thalach | restecg, chol, heartdisease)
# (trestbps _|_ thalach, chol | restecg, heartdisease, exang)
# (trestbps _|_ thalach, chol | restecg, fbs, heartdisease)
# (trestbps _|_ thalach, restecg | chol, heartdisease, sex)
# (trestbps _|_ thalach, restecg, chol | exang, heartdisease, sex)
# (trestbps _|_ thalach, restecg, chol | fbs, heartdisease, sex)
# (trestbps _|_ thalach, restecg | exang, chol, heartdisease)
# (trestbps _|_ thalach, restecg | fbs, chol, heartdisease)
# (trestbps _|_ thalach, restecg, chol | exang, fbs, heartdisease)
# (trestbps _|_ chol | thalach, age, restecg, heartdisease)
# (trestbps _|_ restecg, chol | thalach, age, heartdisease, sex)
# (trestbps _|_ restecg | thalach, age, chol, heartdisease)
# (trestbps _|_ restecg, chol | thalach, age, exang, heartdisease)
# (trestbps _|_ restecg, chol | thalach, age, fbs, heartdisease)
# (trestbps _|_ chol | thalach, restecg, heartdisease, sex)
# (trestbps _|_ chol | thalach, restecg, heartdisease, exang)
# (trestbps _|_ chol | thalach, restecg, fbs, heartdisease)
# (trestbps _|_ restecg | thalach, chol, heartdisease, sex)
# (trestbps _|_ restecg, chol | thalach, exang, heartdisease, sex)
# (trestbps _|_ restecg, chol | thalach, fbs, heartdisease, sex)
# (trestbps _|_ restecg | thalach, exang, chol, heartdisease)
# (trestbps _|_ restecg | thalach, fbs, chol, heartdisease)
# (trestbps _|_ restecg, chol | thalach, exang, fbs, heartdisease)
# (trestbps _|_ thalach, chol | age, restecg, heartdisease, sex)
# (trestbps _|_ thalach | age, restecg, chol, heartdisease)
# (trestbps _|_ thalach, chol | age, restecg, heartdisease, exang)
# (trestbps _|_ thalach, chol | age, restecg, fbs, heartdisease)
# (trestbps _|_ thalach, restecg | age, chol, heartdisease, sex)
# (trestbps _|_ thalach, restecg, chol | age, exang, heartdisease, sex)
# (trestbps _|_ thalach, restecg, chol | age, fbs, heartdisease, sex)
# (trestbps _|_ thalach, restecg | age, exang, chol, heartdisease)
# (trestbps _|_ thalach, restecg | fbs, age, chol, heartdisease)
# (trestbps _|_ thalach, restecg, chol | age, exang, fbs, heartdisease)
# (trestbps _|_ thalach | restecg, chol, heartdisease, sex)
# (trestbps _|_ thalach, chol | restecg, heartdisease, sex, exang)
# (trestbps _|_ thalach, chol | restecg, fbs, heartdisease, sex)
# (trestbps _|_ thalach | restecg, chol, heartdisease, exang)
# (trestbps _|_ thalach | fbs, restecg, chol, heartdisease)
# (trestbps _|_ thalach, chol | restecg, fbs, heartdisease, exang)
# (trestbps _|_ thalach, restecg | exang, chol, heartdisease, sex)
# (trestbps _|_ thalach, restecg | fbs, chol, heartdisease, sex)
# (trestbps _|_ thalach, restecg, chol | exang, fbs, heartdisease, sex)
# (trestbps _|_ thalach, restecg | fbs, exang, chol, heartdisease)
# (trestbps _|_ chol | thalach, age, heartdisease, sex, restecg)
# (trestbps _|_ chol | thalach, age, heartdisease, restecg, exang)
# (trestbps _|_ chol | thalach, age, heartdisease, restecg, fbs)
# (trestbps _|_ restecg | thalach, age, heartdisease, sex, chol)
# (trestbps _|_ restecg, chol | thalach, age, heartdisease, sex, exang)
# (trestbps _|_ restecg, chol | thalach, age, heartdisease, sex, fbs)
# (trestbps _|_ restecg | thalach, age, heartdisease, chol, exang)
# (trestbps _|_ restecg | thalach, age, heartdisease, chol, fbs)
# (trestbps _|_ restecg, chol | thalach, age, heartdisease, exang, fbs)
# (trestbps _|_ chol | thalach, heartdisease, sex, restecg, exang)
# (trestbps _|_ chol | thalach, heartdisease, sex, restecg, fbs)
# (trestbps _|_ chol | thalach, heartdisease, restecg, fbs, exang)
# (trestbps _|_ restecg | thalach, heartdisease, sex, chol, exang)
# (trestbps _|_ restecg | thalach, heartdisease, sex, chol, fbs)
# (trestbps _|_ restecg, chol | thalach, heartdisease, sex, exang, fbs)
# (trestbps _|_ restecg | thalach, heartdisease, chol, exang, fbs)
# (trestbps _|_ thalach | age, heartdisease, sex, chol, restecg)
# (trestbps _|_ thalach, chol | age, heartdisease, sex, restecg, exang)
# (trestbps _|_ thalach, chol | age, heartdisease, sex, restecg, fbs)
# (trestbps _|_ thalach | age, heartdisease, chol, restecg, exang)
# (trestbps _|_ thalach | age, heartdisease, chol, restecg, fbs)
# (trestbps _|_ thalach, chol | age, heartdisease, restecg, fbs, exang)
# (trestbps _|_ thalach, restecg | age, heartdisease, sex, chol, exang)
# (trestbps _|_ thalach, restecg | age, heartdisease, sex, chol, fbs)
# (trestbps _|_ thalach, restecg, chol | age, heartdisease, sex, exang, fbs)
# (trestbps _|_ thalach, restecg | age, heartdisease, chol, exang, fbs)
# (trestbps _|_ thalach | heartdisease, sex, chol, restecg, exang)
# (trestbps _|_ thalach | heartdisease, sex, chol, restecg, fbs)
# (trestbps _|_ thalach, chol | heartdisease, sex, restecg, fbs, exang)
# (trestbps _|_ thalach | heartdisease, chol, restecg, fbs, exang)
# (trestbps _|_ thalach, restecg | heartdisease, sex, chol, exang, fbs)
# (trestbps _|_ chol | thalach, age, heartdisease, sex, restecg, exang)
# (trestbps _|_ chol | thalach, age, heartdisease, sex, restecg, fbs)
# (trestbps _|_ chol | thalach, age, heartdisease, restecg, fbs, exang)
# (trestbps _|_ restecg | thalach, age, heartdisease, sex, chol, exang)
# (trestbps _|_ restecg | thalach, age, heartdisease, sex, chol, fbs)
# (trestbps _|_ restecg, chol | thalach, age, heartdisease, sex, exang, fbs)
# (trestbps _|_ restecg | thalach, age, heartdisease, chol, exang, fbs)
# (trestbps _|_ chol | thalach, heartdisease, sex, restecg, fbs, exang)
# (trestbps _|_ restecg | thalach, heartdisease, sex, chol, exang, fbs)
# (trestbps _|_ thalach | age, heartdisease, sex, chol, restecg, exang)
# (trestbps _|_ thalach | age, heartdisease, sex, chol, restecg, fbs)
# (trestbps _|_ thalach, chol | age, heartdisease, sex, restecg, fbs, exang)
# (trestbps _|_ thalach | age, heartdisease, chol, restecg, fbs, exang)
# (trestbps _|_ thalach, restecg | age, heartdisease, sex, chol, exang, fbs)
# (trestbps _|_ thalach | heartdisease, sex, chol, restecg, fbs, exang)
# (trestbps _|_ chol | thalach, age, heartdisease, sex, restecg, fbs, exang)
# (trestbps _|_ restecg | thalach, age, heartdisease, sex, chol, exang, fbs)
# (trestbps _|_ thalach | age, heartdisease, sex, chol, restecg, fbs, exang)
# (fbs _|_ exang, sex)
# (fbs _|_ exang, sex, trestbps | age)
# (fbs _|_ thalach, restecg, chol | heartdisease)
# (fbs _|_ exang | sex)
# (fbs _|_ sex | exang)
# (fbs _|_ restecg, chol | thalach, heartdisease)
# (fbs _|_ thalach, restecg, chol | age, heartdisease)
# (fbs _|_ exang, trestbps | age, sex)
# (fbs _|_ exang, sex | age, trestbps)
# (fbs _|_ sex, trestbps | age, exang)
# (fbs _|_ thalach, chol | restecg, heartdisease)
# (fbs _|_ thalach, restecg, chol | heartdisease, sex)
# (fbs _|_ thalach, restecg | chol, heartdisease)
# (fbs _|_ thalach, restecg, chol | heartdisease, trestbps)
# (fbs _|_ thalach, restecg, chol | exang, heartdisease)
# (fbs _|_ restecg, chol | thalach, age, heartdisease)
# (fbs _|_ exang, sex | thalach, age, trestbps)
# (fbs _|_ chol | thalach, restecg, heartdisease)
# (fbs _|_ restecg, chol | thalach, heartdisease, sex)
# (fbs _|_ restecg | thalach, chol, heartdisease)
# (fbs _|_ restecg, chol | thalach, heartdisease, trestbps)
# (fbs _|_ restecg, chol | thalach, exang, heartdisease)
# (fbs _|_ thalach, chol | age, restecg, heartdisease)
# (fbs _|_ exang, sex | age, restecg, trestbps)
# (fbs _|_ thalach, restecg, chol | age, heartdisease, sex)
# (fbs _|_ thalach, restecg | age, chol, heartdisease)
# (fbs _|_ thalach, chol, restecg, sex, exang | age, heartdisease, trestbps)
# (fbs _|_ thalach, restecg, chol | age, exang, heartdisease)
# (fbs _|_ exang | age, sex, trestbps)
# (fbs _|_ trestbps | age, exang, sex)
# (fbs _|_ exang, sex | age, chol, trestbps)
# (fbs _|_ sex | age, exang, trestbps)
# (fbs _|_ thalach, chol | restecg, heartdisease, sex)
# (fbs _|_ thalach | restecg, chol, heartdisease)
# (fbs _|_ thalach, chol | restecg, heartdisease, trestbps)
# (fbs _|_ thalach, chol | restecg, heartdisease, exang)
# (fbs _|_ thalach, restecg | chol, heartdisease, sex)
# (fbs _|_ thalach, restecg, chol | heartdisease, sex, trestbps)
# (fbs _|_ thalach, restecg, chol | exang, heartdisease, sex)
# (fbs _|_ thalach, restecg | chol, heartdisease, trestbps)
# (fbs _|_ thalach, restecg | exang, chol, heartdisease)
# (fbs _|_ thalach, restecg, chol | exang, heartdisease, trestbps)
# (fbs _|_ chol | thalach, age, restecg, heartdisease)
# (fbs _|_ exang, sex | thalach, age, restecg, trestbps)
# (fbs _|_ restecg, chol | thalach, age, heartdisease, sex)
# (fbs _|_ restecg | thalach, age, chol, heartdisease)
# (fbs _|_ restecg, chol, sex, exang | thalach, age, heartdisease, trestbps)
# (fbs _|_ restecg, chol | thalach, age, exang, heartdisease)
# (fbs _|_ exang | thalach, age, sex, trestbps)
# (fbs _|_ exang, sex | thalach, age, chol, trestbps)
# (fbs _|_ sex | thalach, age, exang, trestbps)
# (fbs _|_ chol | thalach, restecg, heartdisease, sex)
# (fbs _|_ chol | thalach, restecg, heartdisease, trestbps)
# (fbs _|_ chol | thalach, restecg, heartdisease, exang)
# (fbs _|_ restecg | thalach, chol, heartdisease, sex)
# (fbs _|_ restecg, chol | thalach, heartdisease, sex, trestbps)
# (fbs _|_ restecg, chol | thalach, exang, heartdisease, sex)
# (fbs _|_ restecg | thalach, chol, heartdisease, trestbps)
# (fbs _|_ restecg | thalach, exang, chol, heartdisease)
# (fbs _|_ restecg, chol | thalach, exang, heartdisease, trestbps)
# (fbs _|_ thalach, chol | age, restecg, heartdisease, sex)
# (fbs _|_ thalach | age, restecg, chol, heartdisease)
# (fbs _|_ thalach, exang, chol, sex | age, restecg, heartdisease, trestbps)
# (fbs _|_ thalach, chol | age, restecg, heartdisease, exang)
# (fbs _|_ exang | age, restecg, sex, trestbps)
# (fbs _|_ exang, sex | age, restecg, chol, trestbps)
# (fbs _|_ sex | exang, age, restecg, trestbps)
# (fbs _|_ thalach, restecg | age, chol, heartdisease, sex)
# (fbs _|_ thalach, restecg, chol, exang | age, heartdisease, sex, trestbps)
# (fbs _|_ thalach, restecg, chol | age, exang, heartdisease, sex)
# (fbs _|_ thalach, restecg, sex, exang | age, chol, heartdisease, trestbps)
# (fbs _|_ thalach, restecg | age, exang, chol, heartdisease)
# (fbs _|_ thalach, restecg, chol, sex | age, exang, heartdisease, trestbps)
# (fbs _|_ exang | age, chol, sex, trestbps)
# (fbs _|_ sex | age, exang, chol, trestbps)
# (fbs _|_ thalach | restecg, chol, heartdisease, sex)
# (fbs _|_ thalach, chol | restecg, heartdisease, sex, trestbps)
# (fbs _|_ thalach, chol | restecg, heartdisease, sex, exang)
# (fbs _|_ thalach | restecg, chol, heartdisease, trestbps)
# (fbs _|_ thalach | restecg, chol, heartdisease, exang)
# (fbs _|_ thalach, chol | exang, restecg, heartdisease, trestbps)
# (fbs _|_ thalach, restecg | chol, heartdisease, sex, trestbps)
# (fbs _|_ thalach, restecg | exang, chol, heartdisease, sex)
# (fbs _|_ thalach, restecg, chol | exang, heartdisease, sex, trestbps)
# (fbs _|_ thalach, restecg | exang, chol, heartdisease, trestbps)
# (fbs _|_ chol | thalach, age, heartdisease, sex, restecg)
# (fbs _|_ exang, chol, sex | thalach, age, heartdisease, trestbps, restecg)
# (fbs _|_ chol | thalach, age, heartdisease, restecg, exang)
# (fbs _|_ exang | thalach, age, sex, trestbps, restecg)
# (fbs _|_ exang, sex | thalach, age, chol, trestbps, restecg)
# (fbs _|_ sex | thalach, age, trestbps, restecg, exang)
# (fbs _|_ restecg | thalach, age, heartdisease, sex, chol)
# (fbs _|_ restecg, chol, exang | thalach, age, heartdisease, sex, trestbps)
# (fbs _|_ restecg, chol | thalach, age, heartdisease, sex, exang)
# (fbs _|_ restecg, sex, exang | thalach, age, heartdisease, chol, trestbps)
# (fbs _|_ restecg | thalach, age, heartdisease, chol, exang)
# (fbs _|_ restecg, chol, sex | thalach, age, heartdisease, trestbps, exang)
# (fbs _|_ exang | thalach, age, sex, chol, trestbps)
# (fbs _|_ sex | thalach, age, chol, trestbps, exang)
# (fbs _|_ chol | thalach, heartdisease, sex, trestbps, restecg)
# (fbs _|_ chol | thalach, heartdisease, sex, restecg, exang)
# (fbs _|_ chol | thalach, heartdisease, trestbps, restecg, exang)
# (fbs _|_ restecg | thalach, heartdisease, sex, chol, trestbps)
# (fbs _|_ restecg | thalach, heartdisease, sex, chol, exang)
# (fbs _|_ restecg, chol | thalach, heartdisease, sex, trestbps, exang)
# (fbs _|_ restecg | thalach, heartdisease, chol, trestbps, exang)
# (fbs _|_ thalach | age, heartdisease, sex, chol, restecg)
# (fbs _|_ thalach, exang, chol | age, heartdisease, sex, trestbps, restecg)
# (fbs _|_ thalach, chol | age, heartdisease, sex, restecg, exang)
# (fbs _|_ thalach, exang, sex | age, heartdisease, chol, trestbps, restecg)
# (fbs _|_ thalach | age, heartdisease, chol, restecg, exang)
# (fbs _|_ thalach, chol, sex | age, restecg, heartdisease, trestbps, exang)
# (fbs _|_ exang | age, sex, chol, trestbps, restecg)
# (fbs _|_ sex | age, restecg, chol, trestbps, exang)
# (fbs _|_ thalach, restecg, exang | age, heartdisease, sex, chol, trestbps)
# (fbs _|_ thalach, restecg | age, heartdisease, sex, chol, exang)
# (fbs _|_ thalach, restecg, chol | age, heartdisease, sex, trestbps, exang)
# (fbs _|_ thalach, restecg, sex | age, heartdisease, chol, trestbps, exang)
# (fbs _|_ thalach | heartdisease, sex, chol, trestbps, restecg)
# (fbs _|_ thalach | heartdisease, sex, chol, restecg, exang)
# (fbs _|_ thalach, chol | restecg, heartdisease, sex, trestbps, exang)
# (fbs _|_ thalach | restecg, heartdisease, chol, trestbps, exang)
# (fbs _|_ thalach, restecg | heartdisease, sex, chol, trestbps, exang)
# (fbs _|_ exang, chol | thalach, age, heartdisease, sex, trestbps, restecg)
# (fbs _|_ chol | thalach, age, heartdisease, sex, restecg, exang)
# (fbs _|_ exang, sex | thalach, age, heartdisease, chol, trestbps, restecg)
# (fbs _|_ chol, sex | thalach, age, heartdisease, trestbps, restecg, exang)
# (fbs _|_ exang | thalach, age, sex, chol, trestbps, restecg)
# (fbs _|_ sex | thalach, age, chol, trestbps, restecg, exang)
# (fbs _|_ restecg, exang | thalach, age, heartdisease, sex, chol, trestbps)
# (fbs _|_ restecg | thalach, age, heartdisease, sex, chol, exang)
# (fbs _|_ restecg, chol | thalach, age, heartdisease, sex, trestbps, exang)
# (fbs _|_ restecg, sex | thalach, age, heartdisease, chol, trestbps, exang)
# (fbs _|_ chol | thalach, heartdisease, sex, trestbps, restecg, exang)
# (fbs _|_ restecg | thalach, heartdisease, sex, chol, trestbps, exang)
# (fbs _|_ thalach, exang | age, heartdisease, sex, chol, trestbps, restecg)
# (fbs _|_ thalach | age, heartdisease, sex, chol, restecg, exang)
# (fbs _|_ thalach, chol | age, heartdisease, sex, trestbps, restecg, exang)
# (fbs _|_ thalach, sex | age, heartdisease, chol, trestbps, restecg, exang)
# (fbs _|_ thalach, restecg | age, heartdisease, sex, chol, trestbps, exang)
# (fbs _|_ thalach | heartdisease, sex, chol, trestbps, restecg, exang)
# (fbs _|_ exang | thalach, age, heartdisease, sex, chol, trestbps, restecg)
# (fbs _|_ chol | thalach, age, heartdisease, sex, trestbps, restecg, exang)
# (fbs _|_ sex | thalach, age, heartdisease, chol, trestbps, restecg, exang)
# (fbs _|_ restecg | thalach, age, heartdisease, sex, chol, trestbps, exang)
# (fbs _|_ thalach | age, heartdisease, sex, chol, trestbps, restecg, exang)
# (sex _|_ age, exang, fbs)
# (sex _|_ exang, fbs | age)
# (sex _|_ thalach, restecg, chol | heartdisease)
# (sex _|_ age, fbs | exang)
# (sex _|_ age, exang | fbs)
# (sex _|_ restecg, chol | thalach, heartdisease)
# (sex _|_ thalach, restecg, chol | age, heartdisease)
# (sex _|_ thalach, chol, heartdisease, restecg, fbs | age, trestbps)
# (sex _|_ fbs | age, exang)
# (sex _|_ exang | age, fbs)
# (sex _|_ thalach, chol | restecg, heartdisease)
# (sex _|_ thalach, restecg | chol, heartdisease)
# (sex _|_ thalach, restecg, chol | heartdisease, trestbps)
# (sex _|_ thalach, restecg, chol | exang, heartdisease)
# (sex _|_ thalach, restecg, chol | fbs, heartdisease)
# (sex _|_ thalach, restecg, chol, heartdisease | fbs, trestbps)
# (sex _|_ age | exang, fbs)
# (sex _|_ restecg, chol | thalach, age, heartdisease)
# (sex _|_ fbs, restecg, chol, heartdisease | thalach, age, trestbps)
# (sex _|_ chol | thalach, restecg, heartdisease)
# (sex _|_ restecg | thalach, chol, heartdisease)
# (sex _|_ restecg, chol | thalach, heartdisease, trestbps)
# (sex _|_ restecg, chol | thalach, exang, heartdisease)
# (sex _|_ restecg, chol | thalach, fbs, heartdisease)
# (sex _|_ restecg, chol, heartdisease | thalach, fbs, trestbps)
# (sex _|_ thalach, chol | age, restecg, heartdisease)
# ...
# (thalach _|_ restecg, fbs, trestbps | age, heartdisease, sex, chol, exang)
# (thalach _|_ restecg, exang, trestbps | age, heartdisease, sex, chol, fbs)
# (thalach _|_ chol, restecg, fbs | age, heartdisease, sex, trestbps, exang)
# (thalach _|_ restecg, chol, exang | age, heartdisease, sex, trestbps, fbs)
# (thalach _|_ restecg, chol, trestbps | age, heartdisease, sex, exang, fbs)
# (thalach _|_ restecg, fbs, sex | age, heartdisease, chol, trestbps, exang)
# (thalach _|_ restecg, sex, exang | age, heartdisease, chol, trestbps, fbs)
# (thalach _|_ restecg, sex, trestbps | age, heartdisease, chol, exang, fbs)
# (thalach _|_ restecg, chol, sex | age, heartdisease, trestbps, exang, fbs)
# (thalach _|_ exang | age, sex, chol, trestbps, fbs)
# (thalach _|_ sex | age, chol, trestbps, exang, fbs)
# (thalach _|_ age, exang, fbs | heartdisease, sex, chol, trestbps, restecg)
# (thalach _|_ age, fbs, trestbps | heartdisease, sex, chol, restecg, exang)
# (thalach _|_ age, exang, trestbps | heartdisease, sex, chol, restecg, fbs)
# (thalach _|_ chol, age, fbs | restecg, heartdisease, sex, trestbps, exang)
# (thalach _|_ age, exang, chol | heartdisease, sex, trestbps, restecg, fbs)
# (thalach _|_ age, chol, trestbps | heartdisease, sex, restecg, fbs, exang)
# (thalach _|_ age, fbs, sex | restecg, heartdisease, chol, trestbps, exang)
# (thalach _|_ age, exang, sex | heartdisease, chol, trestbps, restecg, fbs)
# (thalach _|_ age, sex, trestbps | heartdisease, chol, restecg, fbs, exang)
# (thalach _|_ age, chol, sex | restecg, heartdisease, trestbps, exang, fbs)
# (thalach _|_ age, exang | sex, chol, trestbps, restecg, fbs)
# (thalach _|_ age | restecg, sex, trestbps, exang, fbs)
# (thalach _|_ age, sex | restecg, chol, trestbps, exang, fbs)
# (thalach _|_ age, restecg, fbs | heartdisease, sex, chol, trestbps, exang)
# (thalach _|_ age, restecg, exang | heartdisease, sex, chol, trestbps, fbs)
# (thalach _|_ age, restecg, trestbps | heartdisease, sex, chol, exang, fbs)
# (thalach _|_ age, restecg, chol | heartdisease, sex, trestbps, exang, fbs)
# (thalach _|_ age, restecg, sex | heartdisease, chol, trestbps, exang, fbs)
# (thalach _|_ age | sex, chol, trestbps, exang, fbs)
# (thalach _|_ exang, fbs | age, heartdisease, sex, chol, trestbps, restecg)
# (thalach _|_ fbs, trestbps | age, heartdisease, sex, chol, restecg, exang)
# (thalach _|_ exang, trestbps | age, heartdisease, sex, chol, restecg, fbs)
# (thalach _|_ chol, fbs | age, heartdisease, sex, trestbps, restecg, exang)
# (thalach _|_ exang, chol | age, heartdisease, sex, trestbps, restecg, fbs)
# (thalach _|_ chol, trestbps | age, heartdisease, sex, restecg, fbs, exang)
# (thalach _|_ fbs, sex | age, heartdisease, chol, trestbps, restecg, exang)
# (thalach _|_ exang, sex | age, heartdisease, chol, trestbps, restecg, fbs)
# (thalach _|_ sex, trestbps | age, heartdisease, chol, restecg, fbs, exang)
# (thalach _|_ chol, sex | age, restecg, heartdisease, trestbps, exang, fbs)
# (thalach _|_ exang | age, sex, chol, trestbps, restecg, fbs)
# (thalach _|_ sex | age, restecg, chol, trestbps, exang, fbs)
# (thalach _|_ restecg, fbs | age, heartdisease, sex, chol, trestbps, exang)
# (thalach _|_ restecg, exang | age, heartdisease, sex, chol, trestbps, fbs)
# (thalach _|_ restecg, trestbps | age, heartdisease, sex, chol, exang, fbs)
# (thalach _|_ restecg, chol | age, heartdisease, sex, trestbps, exang, fbs)
# (thalach _|_ restecg, sex | age, heartdisease, chol, trestbps, exang, fbs)
# (thalach _|_ age, fbs | heartdisease, sex, chol, trestbps, restecg, exang)
# (thalach _|_ age, exang | heartdisease, sex, chol, trestbps, restecg, fbs)
# (thalach _|_ age, trestbps | heartdisease, sex, chol, restecg, fbs, exang)
# (thalach _|_ age, chol | restecg, heartdisease, sex, trestbps, exang, fbs)
# (thalach _|_ age, sex | restecg, heartdisease, chol, trestbps, exang, fbs)
# (thalach _|_ age | restecg, sex, chol, trestbps, exang, fbs)
# (thalach _|_ age, restecg | heartdisease, sex, chol, trestbps, exang, fbs)
# (thalach _|_ fbs | age, heartdisease, sex, chol, trestbps, restecg, exang)
# (thalach _|_ exang | age, heartdisease, sex, chol, trestbps, restecg, fbs)
# (thalach _|_ trestbps | age, heartdisease, sex, chol, restecg, fbs, exang)
# (thalach _|_ chol | age, heartdisease, sex, trestbps, restecg, fbs, exang)
# (thalach _|_ sex | age, heartdisease, chol, trestbps, restecg, fbs, exang)
# (thalach _|_ restecg | age, heartdisease, sex, chol, trestbps, exang, fbs)
# (thalach _|_ age | heartdisease, sex, chol, trestbps, restecg, fbs, exang)
# (chol _|_ thalach, age, trestbps, restecg, fbs, sex, exang | heartdisease)
# (chol _|_ age, trestbps, restecg, fbs, sex, exang | thalach, heartdisease)
# (chol _|_ thalach, trestbps, restecg, fbs, sex, exang | age, heartdisease)
# (chol _|_ exang, sex | age, trestbps)
# (chol _|_ thalach, age, trestbps, exang, fbs, sex | restecg, heartdisease)
# (chol _|_ thalach, age, trestbps, restecg, fbs, exang | heartdisease, sex)
# (chol _|_ thalach, age, restecg, fbs, sex, exang | heartdisease, trestbps)
# (chol _|_ thalach, age, trestbps, restecg, fbs, sex | exang, heartdisease)
# (chol _|_ thalach, age, trestbps, restecg, sex, exang | fbs, heartdisease)
# (chol _|_ age, exang, sex | fbs, trestbps)
# (chol _|_ trestbps, restecg, fbs, sex, exang | thalach, age, heartdisease)
# (chol _|_ exang, sex | thalach, age, trestbps)
# (chol _|_ age, trestbps, exang, fbs, sex | thalach, restecg, heartdisease)
# (chol _|_ age, trestbps, restecg, fbs, exang | thalach, heartdisease, sex)
# (chol _|_ age, restecg, fbs, sex, exang | thalach, heartdisease, trestbps)
# (chol _|_ age, trestbps, restecg, fbs, sex | thalach, exang, heartdisease)
# (chol _|_ age, trestbps, restecg, sex, exang | thalach, fbs, heartdisease)
# (chol _|_ age, exang, sex | thalach, fbs, trestbps)
# (chol _|_ thalach, trestbps, exang, fbs, sex | age, restecg, heartdisease)
# (chol _|_ exang, sex | age, restecg, trestbps)
# (chol _|_ thalach, trestbps, restecg, fbs, exang | age, heartdisease, sex)
# (chol _|_ thalach, restecg, fbs, sex, exang | age, heartdisease, trestbps)
# (chol _|_ thalach, trestbps, restecg, fbs, sex | age, exang, heartdisease)
# (chol _|_ thalach, trestbps, restecg, sex, exang | age, fbs, heartdisease)
# (chol _|_ exang | age, sex, trestbps)
# (chol _|_ sex | age, exang, trestbps)
# (chol _|_ exang, sex | age, fbs, trestbps)
# (chol _|_ thalach, age, trestbps, exang, fbs | restecg, heartdisease, sex)
# (chol _|_ thalach, age, exang, fbs, sex | restecg, heartdisease, trestbps)
# (chol _|_ thalach, age, trestbps, fbs, sex | restecg, heartdisease, exang)
# (chol _|_ thalach, age, trestbps, exang, sex | restecg, fbs, heartdisease)
# (chol _|_ age, exang, sex | restecg, fbs, trestbps)
# (chol _|_ thalach, age, restecg, fbs, exang | heartdisease, sex, trestbps)
# (chol _|_ thalach, age, trestbps, restecg, fbs | exang, heartdisease, sex)
# (chol _|_ thalach, age, trestbps, restecg, exang | fbs, heartdisease, sex)
# (chol _|_ thalach, age, restecg, fbs, sex | exang, heartdisease, trestbps)
# (chol _|_ thalach, age, restecg, sex, exang | fbs, heartdisease, trestbps)
# (chol _|_ thalach, age, trestbps, restecg, sex | exang, fbs, heartdisease)
# (chol _|_ age, exang | fbs, sex, trestbps)
# (chol _|_ age, sex | exang, fbs, trestbps)
# (chol _|_ exang, fbs, sex, trestbps | thalach, age, restecg, heartdisease)
# (chol _|_ exang, sex | thalach, age, restecg, trestbps)
# (chol _|_ restecg, exang, fbs, trestbps | thalach, age, heartdisease, sex)
# (chol _|_ restecg, fbs, sex, exang | thalach, age, heartdisease, trestbps)
# (chol _|_ restecg, fbs, sex, trestbps | thalach, age, exang, heartdisease)
# (chol _|_ restecg, exang, sex, trestbps | thalach, age, fbs, heartdisease)
# (chol _|_ exang | thalach, age, sex, trestbps)
# (chol _|_ sex | thalach, age, exang, trestbps)
# (chol _|_ exang, sex | thalach, age, fbs, trestbps)
# (chol _|_ age, exang, fbs, trestbps | thalach, restecg, heartdisease, sex)
# (chol _|_ age, exang, fbs, sex | thalach, restecg, heartdisease, trestbps)
# (chol _|_ age, fbs, sex, trestbps | thalach, restecg, heartdisease, exang)
# (chol _|_ age, exang, sex, trestbps | thalach, restecg, fbs, heartdisease)
# (chol _|_ age, exang, sex | thalach, restecg, fbs, trestbps)
# (chol _|_ age, restecg, fbs, exang | thalach, heartdisease, sex, trestbps)
# (chol _|_ age, restecg, fbs, trestbps | thalach, exang, heartdisease, sex)
# (chol _|_ age, exang, restecg, trestbps | thalach, fbs, heartdisease, sex)
# (chol _|_ age, restecg, fbs, sex | thalach, exang, heartdisease, trestbps)
# (chol _|_ age, restecg, sex, exang | thalach, fbs, heartdisease, trestbps)
# (chol _|_ age, restecg, sex, trestbps | thalach, exang, fbs, heartdisease)
# (chol _|_ age, exang | thalach, fbs, sex, trestbps)
# (chol _|_ age, sex | thalach, exang, fbs, trestbps)
# (chol _|_ thalach, exang, fbs, trestbps | age, restecg, heartdisease, sex)
# (chol _|_ thalach, exang, fbs, sex | age, restecg, heartdisease, trestbps)
# (chol _|_ thalach, fbs, sex, trestbps | age, restecg, heartdisease, exang)
# (chol _|_ thalach, exang, sex, trestbps | age, restecg, fbs, heartdisease)
# (chol _|_ exang | age, restecg, sex, trestbps)
# (chol _|_ sex | exang, age, restecg, trestbps)
# (chol _|_ exang, sex | age, restecg, fbs, trestbps)
# (chol _|_ thalach, restecg, fbs, exang | age, heartdisease, sex, trestbps)
# (chol _|_ thalach, restecg, fbs, trestbps | age, exang, heartdisease, sex)
# (chol _|_ thalach, restecg, trestbps, exang | age, fbs, heartdisease, sex)
# (chol _|_ thalach, restecg, fbs, sex | age, exang, heartdisease, trestbps)
# (chol _|_ thalach, restecg, sex, exang | age, fbs, heartdisease, trestbps)
# (chol _|_ thalach, restecg, sex, trestbps | age, exang, fbs, heartdisease)
# (chol _|_ exang | age, fbs, sex, trestbps)
# (chol _|_ sex | age, exang, fbs, trestbps)
# (chol _|_ thalach, age, exang, fbs | restecg, heartdisease, sex, trestbps)
# (chol _|_ thalach, age, fbs, trestbps | restecg, heartdisease, sex, exang)
# (chol _|_ thalach, age, exang, trestbps | restecg, fbs, heartdisease, sex)
# (chol _|_ thalach, age, fbs, sex | exang, restecg, heartdisease, trestbps)
# (chol _|_ thalach, age, exang, sex | restecg, fbs, heartdisease, trestbps)
# (chol _|_ thalach, age, sex, trestbps | restecg, fbs, heartdisease, exang)
# (chol _|_ age, exang | restecg, fbs, sex, trestbps)
# (chol _|_ age, sex | exang, restecg, fbs, trestbps)
# (chol _|_ thalach, age, restecg, fbs | exang, heartdisease, sex, trestbps)
# (chol _|_ thalach, age, restecg, exang | fbs, heartdisease, sex, trestbps)
# (chol _|_ thalach, age, restecg, trestbps | exang, fbs, heartdisease, sex)
# (chol _|_ thalach, age, restecg, sex | exang, fbs, heartdisease, trestbps)
# (chol _|_ age | exang, fbs, sex, trestbps)
# (chol _|_ exang, fbs, trestbps | thalach, age, heartdisease, sex, restecg)
# (chol _|_ exang, fbs, sex | thalach, age, heartdisease, trestbps, restecg)
# (chol _|_ fbs, sex, trestbps | thalach, age, heartdisease, restecg, exang)
# (chol _|_ exang, sex, trestbps | thalach, age, heartdisease, restecg, fbs)
# (chol _|_ exang | thalach, age, sex, trestbps, restecg)
# (chol _|_ sex | thalach, age, trestbps, restecg, exang)
# (chol _|_ exang, sex | thalach, age, trestbps, restecg, fbs)
# (chol _|_ restecg, fbs, exang | thalach, age, heartdisease, sex, trestbps)
# (chol _|_ restecg, fbs, trestbps | thalach, age, heartdisease, sex, exang)
# (chol _|_ restecg, exang, trestbps | thalach, age, heartdisease, sex, fbs)
# (chol _|_ restecg, fbs, sex | thalach, age, heartdisease, trestbps, exang)
# (chol _|_ restecg, sex, exang | thalach, age, heartdisease, trestbps, fbs)
# (chol _|_ restecg, sex, trestbps | thalach, age, heartdisease, exang, fbs)
# (chol _|_ exang | thalach, age, sex, trestbps, fbs)
# (chol _|_ sex | thalach, age, trestbps, exang, fbs)
# (chol _|_ age, exang, fbs | thalach, heartdisease, sex, trestbps, restecg)
# (chol _|_ age, fbs, trestbps | thalach, heartdisease, sex, restecg, exang)
# (chol _|_ age, exang, trestbps | thalach, heartdisease, sex, restecg, fbs)
# (chol _|_ age, fbs, sex | thalach, heartdisease, trestbps, restecg, exang)
# (chol _|_ age, exang, sex | thalach, heartdisease, trestbps, restecg, fbs)
# (chol _|_ age, sex, trestbps | thalach, heartdisease, restecg, fbs, exang)
# (chol _|_ age, exang | thalach, sex, trestbps, restecg, fbs)
# (chol _|_ age, sex | thalach, trestbps, restecg, fbs, exang)
# (chol _|_ age, restecg, fbs | thalach, heartdisease, sex, trestbps, exang)
# (chol _|_ age, restecg, exang | thalach, heartdisease, sex, trestbps, fbs)
# (chol _|_ age, restecg, trestbps | thalach, heartdisease, sex, exang, fbs)
# (chol _|_ age, restecg, sex | thalach, heartdisease, trestbps, exang, fbs)
# (chol _|_ age | thalach, sex, trestbps, exang, fbs)
# (chol _|_ thalach, exang, fbs | age, heartdisease, sex, trestbps, restecg)
# (chol _|_ thalach, fbs, trestbps | age, heartdisease, sex, restecg, exang)
# (chol _|_ thalach, exang, trestbps | age, heartdisease, sex, restecg, fbs)
# (chol _|_ thalach, fbs, sex | age, restecg, heartdisease, trestbps, exang)
# (chol _|_ thalach, exang, sex | age, heartdisease, trestbps, restecg, fbs)
# (chol _|_ thalach, sex, trestbps | age, heartdisease, restecg, fbs, exang)
# (chol _|_ exang | age, sex, trestbps, restecg, fbs)
# (chol _|_ sex | age, restecg, trestbps, exang, fbs)
# (chol _|_ thalach, restecg, fbs | age, heartdisease, sex, trestbps, exang)
# (chol _|_ thalach, restecg, exang | age, heartdisease, sex, trestbps, fbs)
# (chol _|_ thalach, restecg, trestbps | age, heartdisease, sex, exang, fbs)
# (chol _|_ thalach, restecg, sex | age, heartdisease, trestbps, exang, fbs)
# (chol _|_ thalach, age, fbs | restecg, heartdisease, sex, trestbps, exang)
# (chol _|_ thalach, age, exang | heartdisease, sex, trestbps, restecg, fbs)
# (chol _|_ thalach, age, trestbps | heartdisease, sex, restecg, fbs, exang)
# (chol _|_ thalach, age, sex | restecg, heartdisease, trestbps, exang, fbs)
# (chol _|_ age | restecg, sex, trestbps, exang, fbs)
# (chol _|_ thalach, age, restecg | heartdisease, sex, trestbps, exang, fbs)
# (chol _|_ exang, fbs | thalach, age, heartdisease, sex, trestbps, restecg)
# (chol _|_ fbs, trestbps | thalach, age, heartdisease, sex, restecg, exang)
# (chol _|_ exang, trestbps | thalach, age, heartdisease, sex, restecg, fbs)
# (chol _|_ fbs, sex | thalach, age, heartdisease, trestbps, restecg, exang)
# (chol _|_ exang, sex | thalach, age, heartdisease, trestbps, restecg, fbs)
# (chol _|_ sex, trestbps | thalach, age, heartdisease, restecg, fbs, exang)
# (chol _|_ exang | thalach, age, sex, trestbps, restecg, fbs)
# (chol _|_ sex | thalach, age, trestbps, restecg, fbs, exang)
# (chol _|_ restecg, fbs | thalach, age, heartdisease, sex, trestbps, exang)
# (chol _|_ restecg, exang | thalach, age, heartdisease, sex, trestbps, fbs)
# (chol _|_ restecg, trestbps | thalach, age, heartdisease, sex, exang, fbs)
# (chol _|_ restecg, sex | thalach, age, heartdisease, trestbps, exang, fbs)
# (chol _|_ age, fbs | thalach, heartdisease, sex, trestbps, restecg, exang)
# (chol _|_ age, exang | thalach, heartdisease, sex, trestbps, restecg, fbs)
# (chol _|_ age, trestbps | thalach, heartdisease, sex, restecg, fbs, exang)
# (chol _|_ age, sex | thalach, heartdisease, trestbps, restecg, fbs, exang)
# (chol _|_ age | thalach, sex, trestbps, restecg, fbs, exang)
# (chol _|_ age, restecg | thalach, heartdisease, sex, trestbps, exang, fbs)
# (chol _|_ thalach, fbs | age, heartdisease, sex, trestbps, restecg, exang)
# (chol _|_ thalach, exang | age, heartdisease, sex, trestbps, restecg, fbs)
# (chol _|_ thalach, trestbps | age, heartdisease, sex, restecg, fbs, exang)
# (chol _|_ thalach, sex | age, restecg, heartdisease, trestbps, exang, fbs)
# (chol _|_ thalach, restecg | age, heartdisease, sex, trestbps, exang, fbs)
# (chol _|_ thalach, age | restecg, heartdisease, sex, trestbps, exang, fbs)
# (chol _|_ fbs | thalach, age, heartdisease, sex, trestbps, restecg, exang)
# (chol _|_ exang | thalach, age, heartdisease, sex, trestbps, restecg, fbs)
# (chol _|_ trestbps | thalach, age, heartdisease, sex, restecg, fbs, exang)
# (chol _|_ sex | thalach, age, heartdisease, trestbps, restecg, fbs, exang)
# (chol _|_ restecg | thalach, age, heartdisease, sex, trestbps, exang, fbs)
# (chol _|_ age | thalach, heartdisease, sex, trestbps, restecg, fbs, exang)
# (chol _|_ thalach | age, heartdisease, sex, trestbps, restecg, fbs, exang)

# %%
# Doing exact inference using Variable Elimination
from pgmpy.inference import VariableElimination
HeartDisease_infer = VariableElimination(model)

# %%
# Computing the probability of bronc given smoke.
q = HeartDisease_infer.query(variables=['heartdisease'], evidence={'age': 28})
print(q['heartdisease'])
# Out:
# ╒════════════════╤═════════════════════╕
# │ heartdisease   │   phi(heartdisease) │
# ╞════════════════╪═════════════════════╡
# │ heartdisease_0 │              0.5770 │
# ├────────────────┼─────────────────────┤
# │ heartdisease_1 │              0.4230 │
# ╘════════════════╧═════════════════════╛

# %%
q = HeartDisease_infer.query(variables=['heartdisease'], evidence={'chol': 100})
print(q['heartdisease'])
# Out:
# ╒════════════════╤═════════════════════╕
# │ heartdisease   │   phi(heartdisease) │
# ╞════════════════╪═════════════════════╡
# │ heartdisease_0 │              0.5510 │
# ├────────────────┼─────────────────────┤
# │ heartdisease_1 │              0.4490 │
# ╘════════════════╧═════════════════════╛
